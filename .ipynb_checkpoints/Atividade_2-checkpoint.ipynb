# %% [markdown]
# # Aula 1 - Python em Aplicações Ambientais

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\rafael.shibayama\\Documents\\GitHub\\ENS410064\\pyEnv\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd. read_csv('cnuc_2024_02-2.csv', sep=';')
df
# Out:
#       ID_UC     Código UC  Informações Gerais  \
# 0         1  0000.00.0001                 NaN
# 1         2  0000.00.0002                 NaN
# 2         3  0000.00.0003                 NaN
# 3         4  0000.00.0004                 NaN
# 4         5  0000.00.0005                 NaN
# ...     ...           ...                 ...
# 2940   4711  0000.31.4711                 NaN
# 2941   4712  0000.31.4712                 NaN
# 2942   4713  3209.25.4713                 NaN
# 2943   4715  7602.51.4715                 NaN
# 2944   4716  0000.31.4716                 NaN
#
#                                              Nome da UC Esfera Administrativa  \
# 0                ÁREA DE PROTEÇÃO AMBIENTAL ANHATOMIRIM               Federal
# 1        ÁREA DE PROTEÇÃO AMBIENTAL CAVERNAS DO PERUAÇU               Federal
# 2     ÁREA DE PROTEÇÃO AMBIENTAL DA BACIA DO RIO DES...               Federal
# 3     ÁREA DE PROTEÇÃO AMBIENTAL DA BACIA DO RIO SÃO...               Federal
# ...

# %%
df.describe()
# Out:
#              ID_UC  Informações Gerais  Ano do ato legal mais recente  \
# count  2945.000000                 0.0                    2945.000000
# mean   2236.689304                 NaN                    2006.638031
# std    1381.821422                 NaN                      10.760614
# min       1.000000                 NaN                    1941.000000
# 25%    1132.000000                 NaN                    2000.000000
# 50%    2108.000000                 NaN                    2008.000000
# 75%    3454.000000                 NaN                    2015.000000
# max    4716.000000                 NaN                    2024.000000
#
#        Fonte da Área: (1 = SHP, 0 = Ato legal)  Bioma Área (ha)           PI  \
# count                              2945.000000              0.0  2945.000000
# mean                                  0.859762              NaN     0.314771
# std                                   0.347292              NaN     0.464503
# ...

# %%
df.loc[df['RJ'] =='
